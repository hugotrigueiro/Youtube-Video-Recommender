# %%
from IPython.core.display import display, HTML
# display(HTML('<h1>Hello, world!</h1>'))

# %%
from bs4 import BeautifulSoup
# BeautifulSoup(result, "html.parser")

# %%
# import os.path
# from flask import Flask
# import os
# import run_backend
# import time
# import pandas as pd

# app = Flask(__name__)

# queries = ['Data+Science', 'Machine+Learning', 'Curso+de+Estatística']
# limit_page = 2

# def get_predictions():
    
#     new_videos_csv = "new_videos.csv"
#     if not os.path.exists(new_videos_csv):
#         run_backend.update_db(queries, limit_page)
    
#     last_update = os.path.getmtime(new_videos_csv) * 1e9
    
            
#     predictions = []
#     new_videos = pd.read_csv("new_videos.csv", sep=";")
#     for row in new_videos.iterrows():
#         predictions.append((row[1]["video_id"], row[1]["title"], float(row[1]["score"])))
        
#     predictions = sorted(predictions, key=lambda x: x[2], reverse=True)[:30]
        
#     predictions_formatted = []
#     for e in predictions:
#         #print(e)
#         predictions_formatted.append("""<tr>
#                                             <th><a href=\"{link}\">{title}</a></th>
#                                             <th>{score}</th>
#                                         </tr>""".format(title=e[1], link=e[0], score=e[2]))
        
#     return "\n".join(predictions_formatted), last_update


# def main_page():
#     prends, last_update = get_predictions()
#     return """<head><h1>Recomendador de Vídeos do Youtube</h1></head>
#     <body>
#     Segundos desde a última atualização: {}
#     <table>
#         {}
#     </table>
#     </body>""".format((time.time() - last_update) / 1e9, prends)

# %%
import os.path
from flask import Flask
import os
import run_backend
import time
import pandas as pd
import codecs

app = Flask(__name__)

queries = ['Data+Science', 'Machine+Learning', 'Curso+de+Estatística']
limit_page = 4

def get_predictions():
    
    new_videos_csv = "new_videos.csv"
    if not os.path.exists(new_videos_csv):
        run_backend.update_db(queries, limit_page)
    
    last_update = os.path.getmtime(new_videos_csv) * 1e9
    
            
    predictions = []
    new_videos = pd.read_csv("new_videos.csv", sep=";")
    for row in new_videos.iterrows():
        predictions.append((row[1]["video_id"], row[1]["title"], float(row[1]["score"]), row[1]["thumb"]))
        
    predictions = sorted(predictions, key=lambda x: x[2], reverse=True)[:30]
        
    predictions_formatted = []
    carrousel_formatted = []
    for n, e in enumerate(predictions):
        if n == 0:
            carrousel_formatted.append("""<div class="carousel-item active">
            <iframe width="600" height="337" class="iframe-video" src=\"{embed}\" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
            <div>
                <p>Score: <b>{score}</b></p>
            </div>
            </div>""".format(embed=e[0], score=e[2]))
        elif n !=0 and n <= 4:
            carrousel_formatted.append("""<div class="carousel-item">
            <iframe width="600" height="337" class="iframe-video" src=\"{embed}\" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
            <div>
                <p>Score: <b>{score}</b></p>
            </div>
            </div>""".format(embed=e[0], score=e[2]))
            
        
        predictions_formatted.append("""<tr>
                                            <th><a href=\"{link}\">{title}</a></th>
                                            <th>{score}</th>
                                        </tr>""".format(title=e[1], link=e[0], score=e[2]))
        
    return "\n".join(predictions_formatted), "\n".join(carrousel_formatted), last_update


def main_page():
    preds, carrousel, last_update = get_predictions()
    base_html = codecs.open("base_view.html", "r", "utf-8").read().format((time.time() - last_update) / 1e9, carrousel)
    final_html = codecs.open("final_view.html", "r", "utf-8").read()
#     result = base_html
    result = base_html + """
            <table class="table-videos">{}""".format(preds) + final_html
    result = BeautifulSoup(result, "html.parser").prettify().encode()
    view = open("view_complete.html", "wb")
    view.write(result)
    view.close()
#     return render_template("view_complete.html")
    return result

# %%
final_result = main_page()
final_result
# Out:
# True

# %%
from bs4 import BeautifulSoup
BeautifulSoup(final_result, "html.parser")
# Out:
# <!-- VIEW -->
# <html>
# <head>
# <link crossorigin="anonymous" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" rel="stylesheet"/>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet"/>
# </head>
# <body>
# <section id="header">
# <div class="container">
# <h1 class="title">Recomendador de Vídeos do Youtube</h1>
# <h3 class="subtitle">Segundos desde a última atualização: -1586501179.7871888</h3>
# </div>
# </section>
# <section id="bg">
# <div class="overlay">
# <div class="container">
# <h3 class="title-top">Top 5 Vídeos com Maior Score</h3>
# <div class="carousel slide" data-interval="false" data-ride="carousel" id="carouselExampleControls">
# <div class="carousel-inner">
# <div class="carousel-item active">
# ...

# %%
# display(HTML(BeautifulSoup(final_result, "html.parser").prettify()))

# %%
final_result = main_page()
result = final_result.replace("<head><h1>Recomendador de Vídeos do Youtube</h1></head>", 
                        '<head><div id="hero"><h1 class="title">Recomendador de Vídeos do Youtube</h1><div></head><br>')
style = """\n<style>
            #hero {
                background-color: #e74c3c;
                font-family: "Montserrat";
                color: #fff;
            }
            body {
                background-color: #fff;
            }
            .title {
                font-size: 24px;

            }
            </style>"""

result = result + style
BeautifulSoup(result, "html.parser")
# display(HTML(result))
# Out:
# <head><div id="hero"><h1 class="title">Recomendador de Vídeos do Youtube</h1><div></div></div></head><br/>
# <body>
#     Segundos desde a última atualização: -1586461752.812573
#     <table>
# <tr>
# <th><a href="https://www.youtube.com/embed/ykSILAQQu6o">O que é ciência de dados | Nerdologia Tech</a></th>
# <th>0.9825688134784878</th>
# </tr>
# <tr>
# <th><a href="https://www.youtube.com/embed/F608hzn_ygo">Data Science: Introdução a Ciência de Dados (Primeira aula prática programando em Python)</a></th>
# <th>0.972728113485336</th>
# </tr>
# <tr>
# <th><a href="https://www.youtube.com/embed/mhe5e2B9bL8">Machine Learning: como ensinar uma máquina a aprender | Nerdologia Tech</a></th>
# <th>0.9447260764808288</th>
# </tr>
# <tr>
# <th><a href="https://www.youtube.com/embed/-vawLSNdo-A">Como se Tornar um Cientista de Dados de Sucesso // Vlog #105</a></th>
# <th>0.9226356716274412</th>
# </tr>
# <tr>
# ...

# %%
import codecs
file = codecs.open("view.html", "r", "utf-8")
file.read()
# Out:
# '<!-- VIEW -->\n<html>\n\n\n<head>\n    <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">\n    <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.4.1/jquery.min.js"></script>\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/4.7.0/css/font-awesome.min.css">\n</head>\n\n<body>\n    <div id="bg">\n        <div class="overlay minor-height">\n            <div id="hero">\n                <div class="container">\n                    <h1 class="title">Recomendador de Vídeos do Youtube</h1>\n                    <h3 class="subtitle">Segundos desde a última atualização: -1586461752.812573<h3>\n        </div>\n    </div>\n    <div>\n        <div class="container">\n            <h3 class="title-top">Top 5 Vídeos com Maior Score</h3>\n                </div>\n            </div>\n            <di
# ...

# %%
import requests as rq
queries = ['Data+Science', 'Machine+Learning']
a = []
for query in queries:
    r = rq.get("https://www.youtube.com/results?search_query={}&p=1".format(query), timeout=60)
    a.append(r.text)
    print("ok")
# Out:
# ok
# ok

# %%
a
# Out:
# ['  <!DOCTYPE html><html lang="pt-BR" data-cast-api-enabled="true"><head><style name="www-roboto" >@font-face{font-family:\'Roboto\';font-style:italic;font-weight:400;src:local(\'Roboto Italic\'),local(\'Roboto-Italic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:italic;font-weight:500;src:local(\'Roboto Medium Italic\'),local(\'Roboto-MediumItalic\'),url(//fonts.gstatic.com/s/roboto/v18/KFOjCnqEu92Fr1Mu51S7ACc6CsE.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:400;src:local(\'Roboto Regular\'),local(\'Roboto-Regular\'),url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format(\'truetype\');}@font-face{font-family:\'Roboto\';font-style:normal;font-weight:500;src:local(\'Roboto Medium\'),local(\'Roboto-Medium\'),url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format(\'truetype\');}</style><script name="www-roboto" >if (documen
# ...

# %%
del run_backend
# Out:
# -----------------------------------------------------------------------
# NameError                             Traceback (most recent call last)
# <ipython-input-42-aa81a2a6aca6> in <module>
# ----> 1 del run_backend
#
# NameError: name 'run_backend' is not defined

# %%
import requests as rq
from bs4 import BeautifulSoup
import re
def download_search_page(search_word, page):
    search_url = "https://www.youtube.com/results?search_query={}&p={}"
    url = search_url.format(search_word, page)
    url_code = rq.get(url)
    return url_code.text
    

def parse_search_page(page_html):
    parsed = BeautifulSoup(page_html, "html.parser")
    titles = []
    urls_videos = []
    pages_video = []
    
    for link in parsed.findAll("a"):
        if link.has_attr("aria-describedby") == True:
            titles.append(link["title"])
            urlls_videos = "https://youtube.com.br" + link["href"]
            urls_videos.append(urlls_videos)
            pages_video.append(rq.get(urlls_videos).text)
            data = pd.DataFrame({"title": titles, "urls_videos": urls_videos, "pages": pages_video})
    return data


def download_video_page(link):
    video_page = rq.get(link).text
    return video_page


def parse_video_page(page_html):
    parsed = BeautifulSoup(page_html, "html.parser")
    
    class_watch = parsed.find_all(attrs={"class":re.compile(r"watch")})
    id_watch = parsed.find_all(attrs={"id":re.compile(r"watch")})
    channel = parsed.find_all("a", attrs={"href":re.compile(r"channel")})
    meta = parsed.find_all("meta")
    
    got_data = {}
    
    for cl in class_watch:
        colname = "_".join(cl["class"])
        if "clearfix" in colname:
            continue
        got_data[colname] = cl.text.strip()
    
    for cl in id_watch:
        colname = cl["id"]
        got_data[colname] = cl.text.strip()
        
    for cl in meta:
        colname = cl.get("property")
        if colname is not None:
            got_data[colname] = cl["content"]
    
    for n, cl in enumerate(channel):
        got_data["channel_link_{}".format(n)] = cl["href"]
    
    videos_data = pd.DataFrame(got_data, index=range(1))
    selected_columns = ["watch-title", 
                        "watch-view-count", 
                        "watch-time-text", 
                        "content_watch-info-tag-list", 
                        #"watch7-headline", 
                        "watch7-user-header", 
                        #"watch8-sentiment-actions", 
                        "og:image", 
                        "og:image:width", 
                        "og:image:height", 
                        "og:description", 
                        "og:video:width", 
                        "og:video:height", 
                        "og:video:url", 
                        "channel_link_0"]
    
    videos_data = videos_data.reindex(columns=selected_columns)
    return videos_data

# %%
import pandas as pd
import re
import joblib as jb
from scipy.sparse import hstack, csr_matrix
import numpy as np


mdl_lgbm = jb.load("lgbm_20200408.pkl.z")
title_vec = jb.load("titlevec_20200408.pkl.z")


def clean_date(data):
    
    df = data
    date_clean = df["watch-time-text"].str.extract(r"(\d+) de ([a-z]+)\. de (\d+)")
    date_clean[0] = date_clean[0].apply(lambda x: "0" + str(x) if len(str(x)) == 1 else x)

    months_replace = {"jan": "01", 
                      "fev": "02",
                      "mar": "03",
                      "abr": "04",
                      "mai": "05",
                      "jun": "06",
                      "jul": "07",
                      "ago": "08",
                      "set": "09",
                      "out": "10",
                      "nov": "11",
                      "dez": "12"}

    date_clean[1] = date_clean[1].replace(months_replace)
    return pd.to_datetime(date_clean[0] + "/" + date_clean[1] + "/" + date_clean[2], format="%d/%m/%Y")



def clean_views(data):
    df = data
    result = df["watch-view-count"].str.extract(r"(\d+\.?\d+)", expand=False).str.replace(".", "").fillna(0).astype(int).values[0]
    return result



def compute_features(data):
    df = data
    if df["watch-view-count"].isnull().values[0] == True:
        return None
    
    publish_date = clean_date(data)
    if publish_date is None:
        return None
    
    views = clean_views(data)
    title = df["watch-title"].values[0]
    features = pd.DataFrame(index=range(1))
    
    features["tempo_desde_pub"] = (pd.Timestamp.today() - publish_date) / np.timedelta64(1, 'D')
    features["views"] = views
    features["views_por_dia"] = features["views"] / features["tempo_desde_pub"]
    features = features.drop("tempo_desde_pub", axis=1)
    
    vectorized_title = title_vec.transform([title])
    
    num_features = csr_matrix(np.array([features["views"].values[0], 
                                        features["views_por_dia"].values[0]]))
    feature_array = hstack([num_features, vectorized_title])
    
    return feature_array



def compute_prediction(data):
    df = data
    feature_array = compute_features(df)
    
    if feature_array is None:
        return 0
    
    p = mdl_lgbm.predict_proba(feature_array)[0][1]
    df["score"] = p
    return df

# %%
teste = parse_search_page(download_search_page("Data+Science", 1))

# %%
teste2 = teste["urls_videos"].apply(download_video_page).apply(parse_video_page)

# %%
teste2.apply(compute_prediction).apply(lambda x: x["score"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:546: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:546: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:546: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:546: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# C:\ProgramData\Anaconda3\lib\site-packages\lightgbm\basic.py:546: UserWarning: Converting data to scipy sparse matrix.
#   warnings.warn('Converting data to scipy sparse matrix.')
# ...

# %%
df = pd.DataFrame({})
df["title"] = teste2.apply(lambda x: x["watch-title"].values[0])
df["score"] = teste2.apply(lambda x: x["score"].values[0])
df["video_id"] = teste2.apply(lambda x: x["og:video:url"].values[0])

# %%
df
# Out:
#                                                title     score  \
# 0           O que é Data Science? #HipstersPontoTube  0.850588
# 1  Data Science: Introdução a Ciência de Dados (P...  0.972728
# 2                Como é ser data scientist no Nubank  0.542200
#
#                                     video_id
# 0  https://www.youtube.com/embed/5b9Z8toVaAU
# 1  https://www.youtube.com/embed/F608hzn_ygo
# 2  https://www.youtube.com/embed/umq9kCJFavw
